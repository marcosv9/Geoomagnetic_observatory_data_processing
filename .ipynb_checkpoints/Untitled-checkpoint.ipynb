# %%
import pandas as pd
import numpy as np

# %%
shift_data_path = f'MAA0_shift.txt'
df_shift = pd.read_csv(shift_data_path, sep = '\t', index_col = 'Date')

# %%
int(df_shift.loc[df_shift.index == 20210401]['Time-seconds'].values)
# Out:
# 17097

# %%
df_shift
# Out:
#              coef Shift-Time  Time-seconds
# Date
# 20210401  1.00000    4:44:57         17097
# 20210402  1.00000    4:44:51         17091
# 20210403  0.99999    4:44:47         17087
# 20210404  1.00000    4:44:38         17078
# 20210405  0.99997    4:44:32         17072
# 20210406  0.99996    4:44:26         17066
# 20210407  0.99996    4:44:19         17059
# 20210408  1.00000    4:44:13         17053
# 20210409  1.00000    4:44:07         17047
# 20210410  0.99999    4:44:01         17041
# 20210411  1.00000    4:43:51         17031
# 20210412  0.99946    4:43:48         17028
# 20210413  0.99999    4:43:41         17021
# 20210414  1.00000    4:43:34         17014
# 20210415  0.99931    4:43:29         17009
# 20210416  0.99999    4:43:22         17002
# 20210417  1.00000    4:43:15         16995
# 20210418  0.98201    4:43:09         16989
# 20210419  0.99999    4:43:03         16983
# 20210420  1.00000    4:42:57         16977
# 20210421  0.99992    4:42:51         16971
# ...

# %%
start_date = '2021-01-01'
end_date = '2021-01-10'
dates = pd.date_range(start_date,
                                           end_date,
                                           freq = 'D').strftime('%Y%m%d')

for key, value in enumerate(dates):
    print(key)
    print(date)
# Out:
# 0
# 20210109
# 1
# 20210109
# 2
# 20210109
# 3
# 20210109
# 4
# 20210109
# 5
# 20210109
# 6
# 20210109
# 7
# 20210109
# 8
# 20210109
# 9
# 20210109
